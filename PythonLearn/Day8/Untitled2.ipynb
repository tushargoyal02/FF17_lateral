# %%
import pandas as pd

import matplotlib.pyplot as plt

# pip install matplotlib

# %%
df = pd.read_csv("userfoods.csv")

# %%
df
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
df2= df.groupby("Item").mean()


df2=df2.reset_index()

df2
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_8484\141302412.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2= df.groupby("Item").mean()
#         Item      Spend
# 0     Burger  49.780321
# 1    Burrito  49.228810
# 2    Chalupa  52.003537
# 3      Donut  46.838289
# 4  Ice Cream  50.494261
# 5      Sushi  52.668253

# %%
g1 = plt.figure(figsize=(6,3))

plt.bar(x=df2["Item"], height=df2["Spend"], color=["red","blue"])
plt.ylabel("Spend")
plt.xlabel("Items")
plt.xticks(rotation=40)
plt.title("Items for each price")

plt.show()
plt.savefig("bar.png")

# plt.ylim(0,20)
# plt.yticks(0,10)

# %%
plt.pie(df2["Spend"], labels=df2["Item"].values,
       autopct='%.2f',textprops={"fontweight":"bold"})


plt.legend(loc="upper left")
plt.show()

# %%
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_8484\3184396231.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2= df.groupby("Item").mean()

# %%
g1
