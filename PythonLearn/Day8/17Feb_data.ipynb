# %%
import pandas as pd
df = pd.read_csv("NbaInfo.csv")

df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["newSalary"]=1991

# %%
# 7730337
df["newSalary"]= df["Salary"]+100

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  newSalary
# 0                Texas  7730337.0  7730437.0
# ...

# %%
df.insert(1,column="NewName", value="Mr"+df["Name"])

# %%
df
# Out:
#               Name          NewName            Team  Number Position   Age  \
# 0    Avery Bradley  MrAvery Bradley  Boston Celtics     0.0       PG  25.0
# 1      Jae Crowder    MrJae Crowder  Boston Celtics    99.0       SF  25.0
# 2     John Holland   MrJohn Holland  Boston Celtics    30.0       SG  27.0
# 3      R.J. Hunter    MrR.J. Hunter  Boston Celtics    28.0       SG  22.0
# 4    Jonas Jerebko  MrJonas Jerebko  Boston Celtics     8.0       PF  29.0
# ..             ...              ...             ...     ...      ...   ...
# 453   Shelvin Mack   MrShelvin Mack       Utah Jazz     8.0       PG  26.0
# 454      Raul Neto      MrRaul Neto       Utah Jazz    25.0       PG  24.0
# 455   Tibor Pleiss   MrTibor Pleiss       Utah Jazz    21.0        C  26.0
# 456    Jeff Withey    MrJeff Withey       Utah Jazz    24.0        C  26.0
# 457            NaN              NaN             NaN     NaN      NaN   NaN
#
#     Height  Weight            College     Salary  newSalary
# ...

# %%
df.set_index("Name").head(3)
# Out:
#                        NewName            Team  Number Position   Age Height  \
# Name
# Avery Bradley  MrAvery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder      MrJae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# John Holland    MrJohn Holland  Boston Celtics    30.0       SG  27.0    6-5
#
#                Weight            College     Salary  newSalary
# Name
# Avery Bradley   180.0              Texas  7730337.0  7730437.0
# Jae Crowder     235.0          Marquette  6796117.0  6796217.0
# John Holland    205.0  Boston University        NaN        NaN

# %%
df.set_index("Name").reset_index().head(3)
# Out:
#             Name          NewName            Team  Number Position   Age  \
# 0  Avery Bradley  MrAvery Bradley  Boston Celtics     0.0       PG  25.0
# 1    Jae Crowder    MrJae Crowder  Boston Celtics    99.0       SF  25.0
# 2   John Holland   MrJohn Holland  Boston Celtics    30.0       SG  27.0
#
#   Height  Weight            College     Salary  newSalary
# 0    6-2   180.0              Texas  7730337.0  7730437.0
# 1    6-6   235.0          Marquette  6796117.0  6796217.0
# 2    6-5   205.0  Boston University        NaN        NaN

# %%
df.set_index("Name").reset_index(drop=True)
# Out:
#              NewName            Team  Number Position   Age Height  Weight  \
# 0    MrAvery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      MrJae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     MrJohn Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      MrR.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    MrJonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..               ...             ...     ...      ...   ...    ...     ...
# 453   MrShelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      MrRaul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   MrTibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    MrJeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457              NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  newSalary
# ...

# %%
df.set_index("Name",inplace=True,drop=False)

# %%
df.head(1)
# Out:
#                         Name          NewName            Team  Number  \
# Name
# Avery Bradley  Avery Bradley  MrAvery Bradley  Boston Celtics     0.0
#
#               Position   Age Height  Weight College     Salary  newSalary
# Name
# Avery Bradley       PG  25.0    6-2   180.0   Texas  7730337.0  7730437.0

# %%
df.drop("Avery Bradley").head(1)
# Out:
#                     Name        NewName            Team  Number Position  \
# Name
# Jae Crowder  Jae Crowder  MrJae Crowder  Boston Celtics    99.0       SF
#
#               Age Height  Weight    College     Salary  newSalary
# Name
# Jae Crowder  25.0    6-6   235.0  Marquette  6796117.0  6796217.0

# %%
df.drop("Age",axis="columns").head(2)
# Out:
#                         Name Position Height  Weight    College     Salary  \
# Name
# Avery Bradley  Avery Bradley       PG    6-2   180.0      Texas  7730337.0
# Jae Crowder      Jae Crowder       SF    6-6   235.0  Marquette  6796117.0
#
#                newSalary
# Name
# Avery Bradley  7730437.0
# Jae Crowder    6796217.0

# %%
TeamSeries = df.pop("Team")

# %%
del df["Number"]

# %%
df
# Out:
#                         Name Position   Age Height  Weight            College  \
# Name
# Avery Bradley  Avery Bradley       PG  25.0    6-2   180.0              Texas
# Jae Crowder      Jae Crowder       SF  25.0    6-6   235.0          Marquette
# John Holland    John Holland       SG  27.0    6-5   205.0  Boston University
# R.J. Hunter      R.J. Hunter       SG  22.0    6-5   185.0      Georgia State
# Jonas Jerebko  Jonas Jerebko       PF  29.0   6-10   231.0                NaN
# ...                      ...      ...   ...    ...     ...                ...
# Shelvin Mack    Shelvin Mack       PG  26.0    6-3   203.0             Butler
# Raul Neto          Raul Neto       PG  24.0    6-1   179.0                NaN
# Tibor Pleiss    Tibor Pleiss        C  26.0    7-3   256.0                NaN
# Jeff Withey      Jeff Withey        C  26.0    7-0   231.0             Kansas
# NaN                      NaN      NaN   NaN    NaN     NaN                NaN
#
# ...

# %%
df = pd.read_csv("NbaInfo.csv")

df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df[df["College"] == "Texas"]
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
#  df[ condition & cond2]
df.where( df["College"] == "Texas")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1              NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 2              NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 3              NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 4              NaN             NaN     NaN      NaN   NaN    NaN     NaN
# ..             ...             ...     ...      ...   ...    ...     ...
# 453            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 454            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 455            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 456            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#     College     Salary
# 0     Texas  7730337.0
# 1       NaN        NaN
# ...

# %%
df.rename({"College":"New College"}, axis="columns", inplace=True)

# %%
# df.query( df["Team"]== "Boston Celtics")
#  query( expression   =>    Team column  ==  'value' )
# df[df["College"] == "Texas"]
df.query( "Team == 'Boston Celtics'")
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
#  issue is you have a white space in the column name
# df.query( " New College == 'Texas'")
# Out:
# Traceback (most recent call last):
#
#   File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3378 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In [58], line 1
#     df.query( " New College == 'Texas'")
#
#   File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\util\_decorators.py:331 in wrapper
#     return func(*args, **kwargs)
#
#   File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4463 in query
#     res = self.eval(expr, **kwargs)
#
#   File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\util\_decorators.py:331 in wrapper
#     return func(*args, **kwargs)
#
#   File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4601 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
# ...

# %%
# df.rename({newcollege: college})
for data in df.columns:
    newdata = data.replace(" ","")
#     print(data, type(data))
    print(newdata)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# NewCollege
# Salary

# %%
df.columns = [ data.replace(" ","") for data in df.columns]

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'NewCollege', 'Salary'],
#       dtype='object')

# %%
df.query( " NewCollege == 'Texas'")
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight NewCollege      Salary
# 0     180.0      Texas   7730337.0
# 66    190.0      Texas   7000000.0
# 133   245.0      Texas   5500000.0
# 179   238.0      Texas  14260870.0
# ...

# %%
# condition
# query("   expr1  or  expr2       " )

df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#             NewCollege     Salary
# 0                Texas  7730337.0
# ...

# %%
# df[value].apply(func)
# df.dropna(inplace=True)
df["NewCollege"].apply(len)
# df["Name"]=df["Name"]+"Futurense"
# Out:
# 0       5
# 1       9
# 3      13
# 6       3
# 7       7
#        ..
# 449     4
# 451     6
# 452     8
# 453     6
# 456     6
# Name: NewCollege, Length: 364, dtype: int64

# %%
for column in ["Name","NewCollege"]:
    df[column]= df[column].apply(len)

# %%
df
# Out:
#      Name            Team  Number Position   Age Height  Weight  NewCollege  \
# 0      13  Boston Celtics     0.0       PG  25.0    6-2   180.0           5
# 1      11  Boston Celtics    99.0       SF  25.0    6-6   235.0           9
# 3      11  Boston Celtics    28.0       SG  22.0    6-5   185.0          13
# 6      13  Boston Celtics    55.0       PF  21.0    6-8   235.0           3
# 7      12  Boston Celtics    41.0        C  25.0    7-0   238.0           7
# ..    ...             ...     ...      ...   ...    ...     ...         ...
# 449    11       Utah Jazz     5.0       SG  23.0    6-8   206.0           4
# 451    13       Utah Jazz    23.0       SF  26.0    6-6   206.0           6
# 452    10       Utah Jazz    41.0       PF  20.0   6-10   234.0           8
# 453    12       Utah Jazz     8.0       PG  26.0    6-3   203.0           6
# 456    11       Utah Jazz    24.0        C  26.0    7-0   231.0           6
#
#         Salary
# 0    7730337.0
# 1    6796117.0
# ...

# %%
df = pd.read_csv("NbaInfo.csv")

df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.dropna(inplace=True)

# %%
df["Name"].dtype
# Out:
# dtype('O')

# %%
"tushar".upper()
# Out:
# 'TUSHAR'

# %%
"tushar".title()
# Out:
# 'Tushar'

# %%
#  str, int, date
df["Name"].str.upper().str.lower()
# Out:
# 0      avery bradley
# 1        jae crowder
# 3        r.j. hunter
# 6      jordan mickey
# 7       kelly olynyk
#            ...
# 449      rodney hood
# 451    chris johnson
# 452       trey lyles
# 453     shelvin mack
# 456      jeff withey
# Name: Name, Length: 364, dtype: object

# %%
type(df["Name"].str)
# Out:
# pandas.core.strings.accessor.StringMethods

# %%
# df["Name"].str.apply(len)

# %%
df["College"].hasnans
# Out:
# False

# %%
df["College"].str.replace("LSU","Lovely University")
# Out:
# 0                  Texas
# 1              Marquette
# 3          Georgia State
# 6      Lovely University
# 7                Gonzaga
#              ...
# 449                 Duke
# 451               Dayton
# 452             Kentucky
# 453               Butler
# 456               Kansas
# Name: College, Length: 364, dtype: object

# %%
df[ df["College"].str.contains("State") ]
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 3           R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 9          Marcus Smart          Boston Celtics    36.0       PG  22.0    6-4
# 10      Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9
# 12          Evan Turner          Boston Celtics    11.0       SG  27.0    6-7
# 16         Markel Brown           Brooklyn Nets    22.0       SG  24.0    6-3
# 35     Cleanthony Early         New York Knicks    11.0       SF  25.0    6-8
# 39         Kyle O'Quinn         New York Knicks     9.0       PF  26.0   6-10
# 47        Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0    6-0
# 48     Robert Covington      Philadelphia 76ers    33.0       SF  25.0    6-9
# 82       Draymond Green   Golden State Warriors    23.0       PF  26.0    6-7
# 89        Klay Thompson   Golden State Warriors    11.0       SG  26.0    6-7
# ...

# %%
df["College"].str.split(" ").str.get(1).value_counts()
# Out:
# State           37
# Carolina        20
# Tech             8
# Forest           6
# A&M              3
# College          3
# John's           3
# Kentucky         2
# Michigan         2
# Mary's           2
# Mexico           2
# Santa            2
# Dame             2
# Joseph's         2
# (FL)             2
# Valley           1
# Green            1
# Washington       1
# Louis            1
# Beach            1
# Diego            1
# Dominion         1
# Commonwealth     1
# Bonaventure      1
# CC               1
# Name: College, dtype: int64

# %%
df["College"].str.split(" ").str.get(1).value_counts()
# Out:
# State           37
# Carolina        20
# Tech             8
# Forest           6
# A&M              3
# College          3
# John's           3
# Kentucky         2
# Michigan         2
# Mary's           2
# Mexico           2
# Santa            2
# Dame             2
# Joseph's         2
# (FL)             2
# Valley           1
# Green            1
# Washington       1
# Louis            1
# Beach            1
# Diego            1
# Dominion         1
# Commonwealth     1
# Bonaventure      1
# CC               1
# Name: College, dtype: int64

# %%
# North Carolina State	
df [ df["College"].str.contains("State")]
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 3           R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 9          Marcus Smart          Boston Celtics    36.0       PG  22.0    6-4
# 10      Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9
# 12          Evan Turner          Boston Celtics    11.0       SG  27.0    6-7
# 16         Markel Brown           Brooklyn Nets    22.0       SG  24.0    6-3
# 35     Cleanthony Early         New York Knicks    11.0       SF  25.0    6-8
# 39         Kyle O'Quinn         New York Knicks     9.0       PF  26.0   6-10
# 47        Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0    6-0
# 48     Robert Covington      Philadelphia 76ers    33.0       SF  25.0    6-9
# 82       Draymond Green   Golden State Warriors    23.0       PF  26.0    6-7
# 89        Klay Thompson   Golden State Warriors    11.0       SG  26.0    6-7
# ...

# %%
df [ df["College"].str.endswith("State")]
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 3           R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 9          Marcus Smart          Boston Celtics    36.0       PG  22.0    6-4
# 10      Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9
# 12          Evan Turner          Boston Celtics    11.0       SG  27.0    6-7
# 16         Markel Brown           Brooklyn Nets    22.0       SG  24.0    6-3
# 35     Cleanthony Early         New York Knicks    11.0       SF  25.0    6-8
# 39         Kyle O'Quinn         New York Knicks     9.0       PF  26.0   6-10
# 47        Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0    6-0
# 48     Robert Covington      Philadelphia 76ers    33.0       SF  25.0    6-9
# 82       Draymond Green   Golden State Warriors    23.0       PF  26.0    6-7
# 89        Klay Thompson   Golden State Warriors    11.0       SG  26.0    6-7
# ...

# %%
df["College"].str.endswith(" State").value_counts()
# Out:
# False    322
# True      42
# Name: College, dtype: int64

# %%
s=df["College"].str.split(" ").str.get(1)
# Out:
# 0        NaN
# 1        NaN
# 3      State
# 6        NaN
# 7        NaN
#        ...
# 449      NaN
# 451      NaN
# 452      NaN
# 453      NaN
# 456      NaN
# Name: College, Length: 364, dtype: object
